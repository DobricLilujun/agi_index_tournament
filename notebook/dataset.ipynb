# %% [markdown]
# # Dataset Constructions

# %%
from random import random
from typing import List

import importlib

from agi_toolkit.datasets import MMLUMathTester

importlib.reload(MMLUMathTester)
from tqdm import tqdm


tester = MMLUMathTester()

tester.load_data(split="test", limit=100)


def dummy_model(question: str, choices: List[str]) -> str:

    return random.choice(["A", "B", "C", "D"])


print("\n" + "=" * 50)
print("Running MMLU Math Evaluation")
print("=" * 50)
results = tester.run_evaluation(dummy_model, num_samples=20)

tester.save_results()

print("\n" + "=" * 50)
print("Example Question:")
print("=" * 50)
if tester.dataset:
    example = tester.dataset[0]
    print(f"Subject: {example['subject']}")
    print(f"Question: {example['question']}")
    print("Choices:")
    for i, choice in enumerate(example["choices"]):
        print(f"  {chr(65+i)}. {choice}")
    print(f"Correct Answer: {example['answer']}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 6
#       2 from typing import List
#       4 import importlib
# ----> 6 from agi_toolkit.datasets import MMLUMathTester
#       8 importlib.reload(MMLUMathTester)
#       9 from tqdm import tqdm
#
# File ~/projects/agi_index_tournament/.venv/lib/python3.10/site-packages/agi_toolkit/datasets/MMLUMathTester.py:5
#       1 # MMLU (Math) Dataset Testing Code
#       2 # Easy Difficulty - 15k samples
#       3 # Multiple-choice questions across mathematical domains
# ----> 5 from datasets import load_dataset
#       6 import random
#       7 from typing import Dict, List
#
# ModuleNotFoundError: No module named 'datasets'
